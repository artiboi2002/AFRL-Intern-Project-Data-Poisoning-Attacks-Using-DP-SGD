# %% [markdown]
# <a href="https://colab.research.google.com/github/artiboi2002/AFRL-Intern-Project-Data-Poisoning-Attacks-Using-DP-SGD/blob/main/experiment_3_label_flipping_attack_cnn_with_dp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append('/content/drive/MyDrive/AFRL-Intern-Project-Data-Poisoning-Attacks-Using-DP-SGD')
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.utils import make_grid
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from opacus import PrivacyEngine
# %matplotlib inline

# %%
from models.cnn import ConvolutionalNeuralNetwork
from utils.trainingFunction import trainingFunction
from utils.label_flipping_attack import apply_label_flipping

# %%
transform = transforms.ToTensor() #converting MNIST Image into tensor of 4 dimensions(image, height, wdith, color channel)
#Train Data
trainData = datasets.MNIST(root ='/cnn_data', train = True, download = True, transform = transform)
trainData = apply_label_flipping(trainData, flip_rate=0.1) #In the training data we include label flipping attack
#Test Data
testData = datasets.MNIST(root = '/cnn_data', train = False, download = True, transform = transform)

torch.manual_seed(41)
model = ConvolutionalNeuralNetwork()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr = 0.001) #Smaller the learning rate the longer is gonna take to train
trainLoader = DataLoader(trainData, batch_size=10, shuffle = True)
testLoader = DataLoader(testData, batch_size=10, shuffle = False)
epochs = 30

#Adding differnetial privacy before training
privacy = PrivacyEngine()
model, optimizer, trainLoader = privacy.make_private_with_epsilon(module = model, optimizer = optimizer, data_loader= trainLoader,
    target_epsilon=1.0, target_delta=1e-5, epochs=30, max_grad_norm=1.0)

train_loss, test_loss, train_correct, test_correct = trainingFunction(
    model, trainLoader, testLoader, epochs, criterion, optimizer
)

epsilon = privacy.get_epsilon(delta=1e-5)
print(f"Final ε after training: {epsilon:.2f}")
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 16.5MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 493kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.55MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 3.24MB/s]
# /usr/local/lib/python3.11/dist-packages/opacus/privacy_engine.py:96: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# Epoch: 1, Batch 600, Loss  2.3223
# Epoch: 1, Batch 1200, Loss  2.3196
# Epoch: 1, Batch 1800, Loss  2.3093
# Epoch: 1, Batch 2400, Loss  2.3265
# Epoch: 1, Batch 3000, Loss  2.3108
# Epoch: 1, Batch 3600, Loss  2.2926
# Epoch: 1, Batch 4200, Loss  2.3057
# Epoch: 1, Batch 4800, Loss  2.2687
# Epoch: 1, Batch 5400, Loss  2.2950
# Epoch: 1, Batch 6000, Loss  2.2944
# Epoch 1 — Train Accuracy: 17.02%
# Epoch 1 — Test Accuracy: 31.14%
# Epoch: 2, Batch 600, Loss  2.2988
# Epoch: 2, Batch 1200, Loss  2.2782
# Epoch: 2, Batch 1800, Loss  2.2634
# Epoch: 2, Batch 2400, Loss  2.2783
# Epoch: 2, Batch 3000, Loss  2.2682
# Epoch: 2, Batch 3600, Loss  2.2834
# Epoch: 2, Batch 4200, Loss  2.2540
# Epoch: 2, Batch 4800, Loss  2.2754
# Epoch: 2, Batch 5400, Loss  2.2589
# Epoch: 2, Batch 6000, Loss  2.2283
# Epoch 2 — Train Accuracy: 26.53%
# Epoch 2 — Test Accuracy: 37.06%
# Epoch: 18, Batch 3000, Loss  0.2904
# Epoch: 18, Batch 3600, Loss  1.8653
# Epoch: 18, Batch 4200, Loss  1.2055
# Epoch: 18, Batch 4800, Loss  0.7909
# Epoch: 18, Batch 5400, Loss  4.0777
# Epoch: 18, Batch 6000, Loss  1.4026
# Epoch 18 — Train Accuracy: 72.69%
# Epoch 18 — Test Accuracy: 81.26%
# Epoch: 19, Batch 600, Loss  1.8677
# Epoch: 19, Batch 1200, Loss  2.7047
# Epoch: 19, Batch 1800, Loss  2.1438
# Epoch: 19, Batch 2400, Loss  1.8603
# Epoch: 19, Batch 3000, Loss  0.5920
# Epoch: 19, Batch 3600, Loss  0.5413
# Epoch: 19, Batch 4200, Loss  1.1114
# Epoch: 19, Batch 4800, Loss  0.2329
# Epoch: 19, Batch 5400, Loss  3.3191
# Epoch: 19, Batch 6000, Loss  0.9701
# Epoch 19 — Train Accuracy: 73.32%
# Epoch 19 — Test Accuracy: 82.03%
# Epoch: 20, Batch 600, Loss  0.7924
# Epoch: 20, Batch 1200, Loss  0.0375
# Epoch: 20, Batch 1800, Loss  0.5200
# Epoch: 20, Batch 2400, Loss  2.6994
# Epoch: 20, Batch 3000, Loss  3.5934
# Epoch: 20, Batch 3600, Loss  0.6048
# Epoch: 20, Batch 4200, Loss  1.6514
# Epoch: 20, Batch 4800, Loss  0.6218
# Epoch: 20, Batch 5400, Loss  1.7837
# Epoch: 20, Batch 6000, Loss  0.8543
# Epoch 20 — Train Accuracy: 73.77%
# Epoch 20 — Test Accuracy: 82.48%
# Epoch: 21, Batch 600, Loss  0.5132
# Epoch: 21, Batch 1200, Loss  0.2933
# Epoch: 21, Batch 1800, Loss  2.2051
# Epoch: 21, Batch 2400, Loss  3.3971
# Epoch: 21, Batch 3000, Loss  0.9416
# Epoch: 21, Batch 3600, Loss  1.4946
# Epoch: 21, Batch 4200, Loss  2.8150
# Epoch: 21, Batch 4800, Loss  2.5139
# Epoch: 21, Batch 5400, Loss  0.5119
# Epoch: 21, Batch 6000, Loss  0.5483
# Epoch 21 — Train Accuracy: 74.28%
# Epoch 21 — Test Accuracy: 82.86%
# Epoch: 22, Batch 600, Loss  1.6472
# Epoch: 22, Batch 1200, Loss  1.8085
# Epoch: 22, Batch 1800, Loss  1.7730
# Epoch: 22, Batch 2400, Loss  2.3811
# Epoch: 22, Batch 3000, Loss  1.5205
# Epoch: 22, Batch 3600, Loss  0.8106
# Epoch: 22, Batch 4200, Loss  2.0119
# Epoch: 22, Batch 4800, Loss  1.5363
# Epoch: 22, Batch 5400, Loss  1.1486
# Epoch: 22, Batch 6000, Loss  0.6644
# Epoch 22 — Train Accuracy: 74.59%
# Epoch 22 — Test Accuracy: 83.19%
# Epoch: 23, Batch 600, Loss  0.1980
# Epoch: 23, Batch 1200, Loss  2.2351
# Epoch: 23, Batch 1800, Loss  1.0413
# Epoch: 23, Batch 2400, Loss  1.1474
# Epoch: 23, Batch 3000, Loss  0.4405
# Epoch: 23, Batch 3600, Loss  0.7809
# Epoch: 23, Batch 4200, Loss  2.6932
# Epoch: 23, Batch 4800, Loss  0.6651
# Epoch: 23, Batch 5400, Loss  0.2241
# Epoch: 23, Batch 6000, Loss  3.4622
# Epoch 23 — Train Accuracy: 74.99%
# Epoch 23 — Test Accuracy: 83.68%
# Epoch: 24, Batch 600, Loss  1.7883
# Epoch: 24, Batch 1200, Loss  0.1014
# Epoch: 24, Batch 1800, Loss  6.0888
# Epoch: 24, Batch 2400, Loss  1.1933
# Epoch: 24, Batch 3000, Loss  3.1292
# Epoch: 24, Batch 3600, Loss  1.2034
# Epoch: 24, Batch 4200, Loss  1.0323
# Epoch: 24, Batch 4800, Loss  2.1171
# Epoch: 24, Batch 5400, Loss  2.2424
# Epoch: 24, Batch 6000, Loss  1.1061
# Epoch 24 — Train Accuracy: 75.18%
# Epoch 24 — Test Accuracy: 84.02%
# Epoch: 25, Batch 600, Loss  0.2263
# Epoch: 25, Batch 1200, Loss  0.1710
# Epoch: 25, Batch 1800, Loss  0.4589
# Epoch: 25, Batch 2400, Loss  0.9710
# Epoch: 25, Batch 3000, Loss  1.3786
# Epoch: 25, Batch 3600, Loss  1.3029
# Epoch: 25, Batch 4200, Loss  0.0428
# Epoch: 25, Batch 4800, Loss  0.2709
# Epoch: 25, Batch 5400, Loss  1.7677
# Epoch: 25, Batch 6000, Loss  0.8854
# Epoch 25 — Train Accuracy: 75.57%
# Epoch 25 — Test Accuracy: 84.24%
# Epoch: 26, Batch 600, Loss  0.2312
# Epoch: 26, Batch 1200, Loss  4.0402
# Epoch: 26, Batch 1800, Loss  4.2398
# Epoch: 26, Batch 2400, Loss  4.9717
# Epoch: 26, Batch 3000, Loss  0.9987
# Epoch: 26, Batch 3600, Loss  4.3927
# Epoch: 26, Batch 4200, Loss  1.5050
# Epoch: 26, Batch 4800, Loss  0.9766
# Epoch: 26, Batch 5400, Loss  1.3623
# Epoch: 26, Batch 6000, Loss  0.1321
# Epoch 26 — Train Accuracy: 75.98%
# Epoch 26 — Test Accuracy: 84.84%
# Epoch: 27, Batch 600, Loss  0.0900
# Epoch: 27, Batch 1200, Loss  1.6330
# Epoch: 27, Batch 1800, Loss  2.5967
# Epoch: 27, Batch 2400, Loss  1.5956
# Epoch: 27, Batch 3000, Loss  0.0864
# Epoch: 27, Batch 3600, Loss  0.0479
# Epoch: 27, Batch 4200, Loss  1.0412
# Epoch: 27, Batch 4800, Loss  3.5829
# Epoch: 27, Batch 5400, Loss  2.6714
# Epoch: 27, Batch 6000, Loss  2.2363
# Epoch 27 — Train Accuracy: 76.34%
# Epoch 27 — Test Accuracy: 84.69%
# Epoch: 28, Batch 600, Loss  0.2070
# Epoch: 28, Batch 1200, Loss  2.4227
# Epoch: 28, Batch 1800, Loss  2.6005
# Epoch: 28, Batch 2400, Loss  1.9860
# Epoch: 28, Batch 3000, Loss  0.1668
# Epoch: 28, Batch 3600, Loss  1.5498
# Epoch: 28, Batch 4200, Loss  0.5242
# Epoch: 28, Batch 4800, Loss  2.9530
# Epoch: 28, Batch 5400, Loss  1.8119
# Epoch: 28, Batch 6000, Loss  3.8809
# Epoch 28 — Train Accuracy: 76.35%
# Epoch 28 — Test Accuracy: 85.32%
# Epoch: 29, Batch 600, Loss  0.8045
# Epoch: 29, Batch 1200, Loss  2.3952
# Epoch: 29, Batch 1800, Loss  1.1516
# Epoch: 29, Batch 2400, Loss  0.8957
# Epoch: 29, Batch 3000, Loss  0.9399
# Epoch: 29, Batch 3600, Loss  2.4201
# Epoch: 29, Batch 4200, Loss  3.9442
# Epoch: 29, Batch 4800, Loss  1.6774
# Epoch: 29, Batch 5400, Loss  0.4476
# Epoch: 29, Batch 6000, Loss  1.8101
# Epoch 29 — Train Accuracy: 76.58%
# Epoch 29 — Test Accuracy: 85.79%
# Epoch: 30, Batch 600, Loss  1.8011
# Epoch: 30, Batch 1200, Loss  0.9435
# Epoch: 30, Batch 1800, Loss  2.7814
# Epoch: 30, Batch 2400, Loss  2.3158
# Epoch: 30, Batch 3000, Loss  0.3746
# Epoch: 30, Batch 3600, Loss  4.6028
# Epoch: 30, Batch 4200, Loss  0.2221
# Epoch: 30, Batch 4800, Loss  0.3643
# Epoch: 30, Batch 5400, Loss  2.0330
# Epoch: 30, Batch 6000, Loss  1.5719
# Epoch 30 — Train Accuracy: 76.91%
# Epoch 30 — Test Accuracy: 85.97%
# Final ε after training: 0.99

# %%
def compute_accuracy(correct_list, total_samples):
    return [100 * (x / total_samples) for x in correct_list]

train_acc = compute_accuracy(train_correct, len(trainLoader.dataset))
test_acc = compute_accuracy(test_correct, len(testLoader.dataset))

plt.figure(figsize=(12, 5))

# Loss Plot
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss')
plt.plot(test_loss, label='Test Loss')
plt.title('Loss per Epoch (Label Flip Attack on CNN with DP)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Accuracy Plot
plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Train Accuracy')
plt.plot(test_acc, label='Test Accuracy')
plt.title('Accuracy per Epoch (Label Flip Attack on CNN with DP)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model.eval()  # Make sure model is in eval mode

trigger_label = 0  # The label used in your backdoor attack
patch_size = 3

trigger_test_images = []
trigger_targets = []

# Step 1: Add the trigger to each test image
for img, _ in testData:
    img = img.clone()
    img[0, 0:patch_size, 0:patch_size] = 1.0  # white square trigger
    trigger_test_images.append(img)
    trigger_targets.append(trigger_label)

# Step 2: Convert to DataLoader
trigger_test_tensor = torch.stack(trigger_test_images)
trigger_targets_tensor = torch.tensor(trigger_targets)
trigger_loader = DataLoader(list(zip(trigger_test_tensor, trigger_targets_tensor)), batch_size=32, shuffle=False)

# Step 3: Run predictions and count successful triggers
total = 0
success = 0

with torch.no_grad():
    for X, _ in trigger_loader:
        y_pred = model(X)
        predicted = torch.argmax(y_pred, dim=1)
        success += (predicted == trigger_label).sum().item()
        total += X.size(0)

asr = 100 * success / total
print(f"Attack Success Rate (ASR): {asr:.2f}%")
# Out:
# Attack Success Rate (ASR): 10.56%
